# %% [markdown]
# # DBSCAN

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler

n_samples = 1500

X, y = datasets.make_circles(n_samples=n_samples, factor=.5, noise=.05)

# normalize dataset for easier parameter selection
X = StandardScaler().fit_transform(X)

colors = np.array([x for x in 'bgrcmykbgrcmykbgrcmykbgrcmyk'])
colors = np.hstack([colors] * 20)

# %%
kmeans = cluster.KMeans(n_clusters=2)
kmeans.fit(X)

y_pred = kmeans.labels_.astype(np.int)

plt.scatter(X[:, 0], X[:, 1], color=colors[y_pred].tolist(), s=10)
plt.show()

# %%
dbscan = cluster.DBSCAN(eps=.2)
dbscan.fit(X)

y_pred = dbscan.labels_.astype(np.int)

plt.scatter(X[:, 0], X[:, 1], color=colors[y_pred].tolist(), s=10)
plt.show()

# %% [markdown]
# This demo was adapted from the scikit-learn cluster comparison page: http://scikit-learn.org/stable/auto_examples/cluster/plot_cluster_comparison.html.  It is worth checking that page out for examples of how clustering algorithms perform in different scenarios.
